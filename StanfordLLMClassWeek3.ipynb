# %% [markdown]
# <a href="https://colab.research.google.com/github/imusicmash/stanford_llm_python/blob/main/StanfordLLMClassWeek3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stanford LLM class week 3
#StanfordTech16

# %%
# !pip install openai
# !pip install sentence-transformers
# !pip install langchain pypdf langchain-openai #tiktoken chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 77.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Embeddings

# %%
import pandas as pd

df = pd.read_csv('http://bit.ly/dataset-sst2',
                 nrows=100, sep='\t', names=['text', 'label'])

df['label'] = df['label'].replace({0: 'negative', 1: 'positive'})

# %%
df.head()
# Out:
#                                                 text     label
# 0  a stirring , funny and finally transporting re...  positive
# 1  apparently reassembled from the cutting room f...  negative
# 2  they presume their audience wo n't sit still f...  negative
# 3  this is a visually stunning rumination on love...  positive
# 4  jonathan parker 's bartleby should have been t...  positive

# %%
df.tail()
# Out:
#                                                  text     label
# 95                      leigh makes these lives count  positive
# 96  ambitious , unsettling psychodrama that takes ...  positive
# 97  the woodman seems to have directly influenced ...  positive
# 98               i could n't recommend this film more  positive
# 99  an inexperienced director , mehta has much to ...  negative

# %%
# number of rows * number of columns
df.size
# Out:
# 200

# %%
# hf hosts this library
# https://huggingface.co/sentence-transformers
from sentence_transformers import SentenceTransformer

sentence_bert_model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
# distillbert is pretrained to predict masked words in a sequence of text
# an hidden state or layer (lower dimension) for the input token is the embedding
#sentence transformers provides the 768 length

# the next function will take in a dataframe
def get_embeddings(sentences):
    return sentence_bert_model.encode(sentences,
                                    batch_size=32,
                                    show_progress_bar=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name sentence-transformers/distilbert-base-nli-stsb-mean-tokens. Creating a new one with MEAN pooling.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
e = get_embeddings(df['text'])
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Convert NumPy array of embedding into data frame
embedding_df = pd.DataFrame(e)

# Save dataframe as as TSV file without any index and header
embedding_df.to_csv('output.tsv', sep='\t', index=None, header=None)

# %%
embedding_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.007687  0.220589  1.107231 -0.805425 -0.189138  0.175037 -0.095774
# 1  0.131850 -1.051062  0.379231 -0.066255 -0.299080 -0.981429  0.958281
# 2  0.146425  0.026572  0.910158 -0.720146 -0.057320  0.184523 -0.354749
# 3  0.725216  0.400027  0.550634 -0.415071  0.321566  0.476579 -0.268125
# 4  0.386161  0.437597 -0.229873 -0.328632  0.146724  0.166341  0.614475
#
#         7         8         9    ...       758       759       760       761  \
# 0 -1.149740  0.614676 -0.406313  ... -0.091128 -0.930857 -0.770217  0.830264
# 1 -0.036092 -0.081782 -0.722953  ...  0.048543 -0.194993  0.429362  1.433621
# 2 -0.819163  0.438383 -0.083151  ... -0.953809  0.045402 -0.156494 -0.422206
# 3  0.285532 -0.096130 -0.754695  ... -0.834957 -0.458782 -0.016415  0.061812
# 4 -0.451549 -0.415271  0.054352  ... -0.144842 -0.170682  0.482450  0.865260
#
#         762       763       764       765       766       767
# ...

# %%
# Save dataframe without any index
df.to_csv('metadata.tsv', index=False, sep='\t')

# %%
df.head()
# Out:
#                                                 text     label
# 0  a stirring , funny and finally transporting re...  positive
# 1  apparently reassembled from the cutting room f...  negative
# 2  they presume their audience wo n't sit still f...  negative
# 3  this is a visually stunning rumination on love...  positive
# 4  jonathan parker 's bartleby should have been t...  positive

# %% [markdown]
# Embeddings projector link: https://projector.tensorflow.org/

# %% [markdown]
# # Standard imports

# %%
from openai import OpenAI
from google.colab import userdata

open_ai_key = userdata.get('openai')
client = OpenAI(api_key=open_ai_key)

# %% [markdown]
# # Langchain & summarizing PDF's

# %%
# Get a PDF
# !wget https://arxiv.org/pdf/2401.16212.pdf
# Out:
# --2024-02-28 22:36:17--  https://arxiv.org/pdf/2401.16212.pdf
# Resolving arxiv.org (arxiv.org)... 151.101.3.42, 151.101.67.42, 151.101.195.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.3.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 512852 (501K) [application/pdf]
# Saving to: ‘2401.16212.pdf’
#
# 2401.16212.pdf      100%[===================>] 500.83K  --.-KB/s    in 0.05s
#
# 2024-02-28 22:36:17 (10.3 MB/s) - ‘2401.16212.pdf’ saved [512852/512852]

# %%
# !ls
# Out:
# 2401.16212.pdf	sample_data

# %%
# !wget https://www.morganstanley.com/im/publication/insights/articles/article_increasingreturns.pdf
# Out:
# --2024-02-14 19:20:32--  https://www.morganstanley.com/im/publication/insights/articles/article_increasingreturns.pdf
# Resolving www.morganstanley.com (www.morganstanley.com)... 104.115.172.233
# Connecting to www.morganstanley.com (www.morganstanley.com)|104.115.172.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘article_increasingreturns.pdf.1’
#
# article_increasingr     [ <=>                ] 570.73K  --.-KB/s    in 0.1s
#
# 2024-02-14 19:20:33 (4.78 MB/s) - ‘article_increasingreturns.pdf.1’ saved [584426]

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("2401.16212.pdf")
pages = loader.load_and_split()

# %%
pages[0:1]
# Out:
# [Document(page_content='Better Call GPT, Comparing Large Language Models Against Lawyers\nLAUREN MARTIN, NICK WHITEHOUSE, STEPHANIE YIU, LIZZIE CATTERSON, RIVINDU\nPERERA, AI Center of Excellence, Onit Inc., New Zealand\nThis paper presents a groundbreaking comparison between Large Language Models (LLMs) and traditional legal contract review-\ners—Junior Lawyers and Legal Process Outsourcers (LPOs). We dissect whether LLMs can outperform humans in accuracy, speed,\nand cost-efficiency during contract review. Our empirical analysis benchmarks LLMs against a ground truth set by Senior Lawyers,\nuncovering that advanced models match or exceed human accuracy in determining legal issues. In speed, LLMs complete reviews in\nmere seconds, eclipsing the hours required by their human counterparts. Cost-wise, LLMs operate at a fraction of the price, offering a\nstaggering 99.97 percent reduction in cost over traditional methods. These results are not just statistics—they signal a seismic shift
# ...

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain_community.document_loaders import WebBaseLoader
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0.1, model_name="gpt-4-turbo-preview", api_key=open_ai_key) # change this to work any other providers
chain = load_summarize_chain(llm, chain_type="stuff")
# stuff or map reduce
# stuff is take all the text available and stuff it into context window.. good for token length <128k
# if u have more than what fits incontext window, u can do map reduce.. summary of parts of text individually then summary of summaries

chain.run(pages[0:3])
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ...

# %%
chain.run(pages[0:1])
# Out:
# "This paper, authored by Lauren Martin and colleagues from Onit Inc.'s AI Center of Excellence in New Zealand, presents a pioneering study comparing the performance of Large Language Models (LLMs) with that of human legal professionals, specifically Junior Lawyers and Legal Process Outsourcers (LPOs), in the task of legal contract review. The study evaluates the accuracy, speed, and cost-efficiency of LLMs in identifying legal issues within contracts, benchmarking their performance against a standard set by Senior Lawyers. The findings reveal that LLMs not only match but in some cases exceed the accuracy of their human counterparts, complete tasks significantly faster (in seconds compared to hours), and operate at a substantially lower cost, achieving a 99.97 percent reduction compared to traditional methods. These results suggest a transformative potential for LLMs in the legal industry, indicating a shift towards more accessible and efficient legal services and heralding an era whe
# ...

# %%
# langchain constructs the prompt to make the model behave in certain ways.
# we're passing it all directly here in this prompt.. don't need the system prompt any more.

from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate

# Define prompt
prompt_template = """Write a concise summary in a maximum of 6 bullets of the following text enclosed within three backticks:
```{text}```
CONCISE SUMMARY:"""
prompt = PromptTemplate.from_template(prompt_template)

# Define LLM chain
llm = ChatOpenAI(temperature=0, model_name="gpt-4-turbo-preview", api_key=open_ai_key)
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Define StuffDocumentsChain
stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")

print(stuff_chain.run(pages[0:3]))
# Out:
# - The paper evaluates the performance of Large Language Models (LLMs) against Junior Lawyers and Legal Process Outsourcers (LPOs) in legal contract review, focusing on accuracy, speed, and cost-efficiency.
# - Empirical analysis shows LLMs match or exceed human accuracy in identifying legal issues, complete reviews significantly faster, and operate at a 99.97% lower cost.
# - The study indicates a potential paradigm shift in legal practice, suggesting LLMs could significantly enhance the accessibility and efficiency of legal services.
# - It addresses a gap in research regarding the application of Generative AI and LLMs in legal issue identification, aiming to understand their capabilities in high volume legal tasks.
# - The research contributes to the understanding of LLMs' potential and limitations in the legal domain, offering insights for legal and AI practitioners.
# ...

# %%
# change the personality
# Define prompt
prompt_template = """You are a pirate and should speak in pirate language. Write a concise summary in a maximum of 3+2 bullets of the following text enclosed within three backticks:
```{text}```
CONCISE SUMMARY:"""
prompt = PromptTemplate.from_template(prompt_template)

# Define LLM chain
llm = ChatOpenAI(temperature=0, model_name="gpt-4-turbo-preview", api_key=open_ai_key)
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Define StuffDocumentsChain
stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")

print(stuff_chain.run(pages[0:3]))
# Out:
# Arrr, mateys, let's set sail on a voyage through the findings of this scholarly paper, "Better Call GPT, Comparing Large Language Models Against Lawyers":
#
# - The scallywags at Onit Inc., New Zealand, embarked on a quest to see if Large Language Models (LLMs) could outdo Junior Lawyers and Legal Process Outsourcers (LPOs) in reviewing legal contracts, focusing on accuracy, speed, and cost-efficiency.
# - By comparing these LLMs to a ground truth set by Senior Lawyers, it was discovered that these advanced models be matching or even besting human accuracy in spotting legal issues, completing reviews in mere seconds, and costing a mere fraction of traditional methods, signaling a major shift in how legal practices might operate.
#
# Additional findings:
# - This research be not just for show; it suggests we be on the cusp of an era where LLMs dominate legal contract review, challenging the old ways and envisioning a future where legal services be more accessible and efficient.
# ...

# %% [markdown]
# # RAG

# %%
# !pip install llama-index --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 61.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 49.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 58.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 100.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 48.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pypdf

# %%
# !wget https://www.goldmansachs.com/intelligence/pages/gs-research/2024-us-equity-outlook-all-you-had-to-do-was-stay/report.pdf
# Out:
# --2024-02-28 22:47:54--  https://www.goldmansachs.com/intelligence/pages/gs-research/2024-us-equity-outlook-all-you-had-to-do-was-stay/report.pdf
# Resolving www.goldmansachs.com (www.goldmansachs.com)... 23.213.120.152
# Connecting to www.goldmansachs.com (www.goldmansachs.com)|23.213.120.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 491250 (480K) [application/pdf]
# Saving to: ‘report.pdf’
#
# report.pdf          100%[===================>] 479.74K  --.-KB/s    in 0.06s
#
# 2024-02-28 22:47:55 (7.91 MB/s) - ‘report.pdf’ saved [491250/491250]

# %%
import os
os.environ["OPENAI_API_KEY"] = open_ai_key

# %%
# Import necessary classes from the llama_index package
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# Read documents from the specified directory and load a specific document, "report.pdf".
documents = SimpleDirectoryReader("./").load_data("report.pdf")

# Create a VectorStoreIndex object from the documents. This will involve processing the documents
# and creating a vector representation for each of them, suitable for semantic searching.
index = VectorStoreIndex.from_documents(documents)

# Convert the VectorStoreIndex object into a query engine. This query engine can be used to
# perform semantic searches on the index, matching natural language queries to the most relevant
# documents in the index.
query_engine = index.as_query_engine()

# Use the query engine to search for documents that are relevant to the query
# from the indexed documents based on the semantic understanding of the query.
response = query_engine.query("What is the 2024 outlook for US GDP?")

# Print the response obtained from the query. This will display the result of the semantic search,
# showing the information or documents that best match the query about the 2024 outlook.
print(response)
# Out:
# Loading files: 100%|██████████| 2/2 [00:01<00:00,  1.55file/s]
# The 2024 outlook for US GDP is forecasted to be above-consensus with a growth rate of 2.1%.

# %%
# my own question
response = query_engine.query("What are the S&P 500 ex-Energy margin trends?")
print(response)
# Out:
# The S&P 500 ex-Energy net profit margins troughed in 4Q 2022 and have sequentially improved for three consecutive quarters. However, resilient input cost growth, rising interest expense, and higher effective tax rates will allow only minimal margin expansion in 2024. Instead, profit growth will equal sales growth.

# %%
# in the class on feb 21.. he asked What did i just asked
#and it got confused.. it doesn't know
#it's stateless
# he asked about keeping track of memory
# just change one line of code.
# index.as_query_engine becomes index.as_chat_engine !!
#try this
chat_engine = index.as_chat_engine(chat_mode="openai")
response = chat_engine.chat("Hi there")
print(response)
chat_engine.chat("What is the likelihood of recession in 2024?")
chat_engine.chat("What did i just ask")
# then it should work correctly.
# why.. in the backend, each time it asks a question, it's capturing that and passing that back in.. and saying history so far.
chat_engine = index.as_chat_engine(chat_mode="openai", verbose=True)
# everything is passed back into memory

# %% [markdown]
# # Homework

# %% [markdown]
# 1. Create a summarization using langchain and compare the "stuff" and "map-reduce" methods
# 2. Create a simple RAG system over a knowledge base of your choice

# %%
# RAG example
# i looked up how to pull in multiple documents from a a directory.. it's like this:
# documents = SimpleDirectoryReader("./my_documents").load_data()

# !wget https://www.thinkwithgoogle.com/_qs/documents/8554/Kantar_Millward_Brown_The_Role_of_Youtube_in_Brand_Building.PDF

# !wget https://www.thinkwithgoogle.com/_qs/documents/7366/YT_Effectiveness_Guide_CEE_Final_-_Interactive_Version._heFslE1.pdf
# Out:
# --2024-02-28 22:52:11--  https://www.thinkwithgoogle.com/_qs/documents/8554/Kantar_Millward_Brown_The_Role_of_Youtube_in_Brand_Building.PDF
# Resolving www.thinkwithgoogle.com (www.thinkwithgoogle.com)... 142.250.103.141, 2607:f8b0:4001:c2b::8d
# Connecting to www.thinkwithgoogle.com (www.thinkwithgoogle.com)|142.250.103.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9744703 (9.3M) [application/pdf]
# Saving to: ‘Kantar_Millward_Brown_The_Role_of_Youtube_in_Brand_Building.PDF’
#
# Kantar_Millward_Bro 100%[===================>]   9.29M  --.-KB/s    in 0.08s
#
# 2024-02-28 22:52:12 (118 MB/s) - ‘Kantar_Millward_Brown_The_Role_of_Youtube_in_Brand_Building.PDF’ saved [9744703/9744703]
#
# --2024-02-28 22:52:12--  https://www.thinkwithgoogle.com/_qs/documents/7366/YT_Effectiveness_Guide_CEE_Final_-_Interactive_Version._heFslE1.pdf
# Resolving www.thinkwithgoogle.com (www.thinkwithgoogle.com)... 142.250.103.141, 2607:f8b0:4001:c2b::8d
# ...

# %%
# Import necessary classes from the llama_index package
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# Read documents from the specified directory and load a specific document, "report.pdf".
#documents = SimpleDirectoryReader("./pdf/").load_data()
documents = SimpleDirectoryReader("/").load_data()

# %%
documents
# Out:
# [Document(id_='aaf6d559-0b9c-4264-a9a9-39a05387b206', embedding=None, metadata={'file_path': '/NGC-DL-CONTAINER-LICENSE', 'file_name': '/NGC-DL-CONTAINER-LICENSE', 'file_type': None, 'file_size': 17294, 'creation_date': '2024-02-27', 'last_modified_date': '2023-11-10', 'last_accessed_date': None}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='NVIDIA DEEP LEARNING CONTAINER LICENSE\n\nThis license is a legal agreement between you and NVIDIA Corporation ("NVIDIA")\nand governs the use of the NVIDIA container and all its contents (“CONTAINER”).\n\nThis license can be accepted only by an adult of legal age of majority in the\ncountry in which the CONTAINER is used. If you are under the legal age of\nmajority, you must ask your parent or legal guardian to
# ...

# %%
# Create a VectorStoreIndex object from the documents. This will involve processing the documents
# and creating a vector representation for each of them, suitable for semantic searching.
index = VectorStoreIndex.from_documents(documents)

# Convert the VectorStoreIndex object into a query engine. This query engine can be used to
# perform semantic searches on the index, matching natural language queries to the most relevant
# documents in the index.
query_engine = index.as_query_engine()

# Use the query engine to search for documents that are relevant to the query
# from the indexed documents based on the semantic understanding of the query.
response = query_engine.query("What are the tips I should follow for increasing brand awareness and recall KPIs?")

# Print the response obtained from the query. This will display the result of the semantic search,
# showing the information or documents that best match the query about the 2024 outlook.
print(response)
# Out:
# To increase brand awareness and recall KPIs, you should focus on creating a fully immersive video experience that engages users with both sight and sound. Utilize YouTube's platform where viewers are more receptive to watching and listening to ads. Additionally, consider going beyond traditional demographic targeting by leveraging signals from user behavior and search patterns to target based on likely intent. Lastly, plan your YouTube campaigns alongside TV placements to maximize impact, as combining both mediums has shown to improve brand results at the top of the funnel.

# %%
#.. cool very good..it basically summarized the 3 points on page 8
